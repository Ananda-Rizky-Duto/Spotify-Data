# %% [markdown]
# <a href="https://colab.research.google.com/github/AnandaRizky99/Spotify-Data/blob/master/Spotify_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Persiapan**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import lightgbm as lgb
import seaborn as sns
import csv

# %% [markdown]
# # **Pengecekan Data**

# %%
top2017 = pd.read_csv('https://raw.githubusercontent.com/AnandaRizky99/Spotify-Data/master/top%20100%202017.csv')
top2017.head(100)
# Out:
#                        id  ... time_signature
# 0   7qiZfU4dY1lWllzX7mPBI  ...            4.0
# 1   5CtI0qwDJkDQGwXD1H1cL  ...            4.0
# 2   4aWmUDTfIPGksMNLV2rQP  ...            4.0
# 3   6RUKPb4LETWmmr3iAEQkt  ...            4.0
# 4   3DXncPQOG4VBw3QHh3S81  ...            4.0
# ..                    ...  ...            ...
# 95  1PSBzsahR2AKwLJgx8ehB  ...            4.0
# 96  0QsvXIfqM0zZoerQfsI9l  ...            4.0
# 97  7mldq42yDuxiUNn08nvzH  ...            4.0
# 98  7i2DJ88J7jQ8K7zqFX2fW  ...            4.0
# 99  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
#
# [100 rows x 16 columns]

# %%
top2018 = pd.read_csv('https://raw.githubusercontent.com/AnandaRizky99/Spotify-Data/master/top%20100%202018.csv')
top2018.head(100)
# Out:
#                        id  ... time_signature
# 0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1   3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2   0e7ipj03S05BNilyu5bRz  ...            4.0
# 3   3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
# ..                    ...  ...            ...
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [100 rows x 16 columns]

# %% [markdown]
# # **Analisa Data**

# %%
print("Analisa Data Danceability\n")
print("2017")
print(top2017['danceability'].describe())
print("\n2018")
print(top2018['danceability'].describe())
# Out:
# Analisa Data Danceability
#
# 2017
# count    100.00000
# mean       0.69682
# std        0.12508
# min        0.25800
# 25%        0.63500
# 50%        0.71400
# 75%        0.77025
# max        0.92700
# Name: danceability, dtype: float64
#
# 2018
# count    100.00000
# mean       0.71646
# std        0.13107
# min        0.25800
# 25%        0.63550
# 50%        0.73300
# 75%        0.79825
# max        0.96400
# Name: danceability, dtype: float64

# %%
print("Analisa Data Energy\n")
print("2017")
print(top2017['energy'].describe())
print("\n2018")
print(top2018['energy'].describe())
# Out:
# Analisa Data Energy
#
# 2017
# count    100.000000
# mean       0.660690
# std        0.139207
# min        0.346000
# 25%        0.556500
# 50%        0.667500
# 75%        0.787500
# max        0.932000
# Name: energy, dtype: float64
#
# 2018
# count    100.000000
# mean       0.659060
# std        0.145067
# min        0.296000
# 25%        0.562000
# 50%        0.678000
# 75%        0.772250
# max        0.909000
# Name: energy, dtype: float64

# %%
print("Analisa Data Key\n")
print("2017")
print(top2017['key'].describe())
print("\n2018")
print(top2018['key'].describe())
# Out:
# Analisa Data Key
#
# 2017
# count    100.000000
# mean       5.570000
# std        3.731534
# min        0.000000
# 25%        2.000000
# 50%        6.000000
# 75%        9.000000
# max       11.000000
# Name: key, dtype: float64
#
# 2018
# count    100.000000
# mean       5.330000
# std        3.676447
# min        0.000000
# 25%        1.750000
# 50%        5.000000
# 75%        8.250000
# max       11.000000
# Name: key, dtype: float64

# %%
print("Analisa Data Loudness\n")
print("2017")
print(top2017['loudness'].describe())
print("\n2018")
print(top2018['loudness'].describe())
# Out:
# Analisa Data Loudness
#
# 2017
# count    100.000000
# mean      -5.652650
# std        1.802067
# min      -11.462000
# 25%       -6.594500
# 50%       -5.437000
# 75%       -4.326750
# max       -2.396000
# Name: loudness, dtype: float64
#
# 2018
# count    100.000000
# mean      -5.677640
# std        1.777577
# min      -10.109000
# 25%       -6.650500
# 50%       -5.566500
# 75%       -4.363750
# max       -2.384000
# Name: loudness, dtype: float64

# %%
print("Analisa Data Mode\n")
print("2017")
print(top2017['mode'].describe())
print("\n2018")
print(top2018['mode'].describe())
# Out:
# Analisa Data Mode
#
# 2017
# count    100.000000
# mean       0.580000
# std        0.496045
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: mode, dtype: float64
#
# 2018
# count    100.000000
# mean       0.590000
# std        0.494311
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: mode, dtype: float64

# %%
print("Analisa Data Speechiness\n")
print("2017")
print(top2017['speechiness'].describe())
print("\n2018")
print(top2018['speechiness'].describe())
# Out:
# Analisa Data Speechiness
#
# 2017
# count    100.000000
# mean       0.103969
# std        0.095115
# min        0.023200
# 25%        0.043125
# 50%        0.062650
# 75%        0.123000
# max        0.431000
# Name: speechiness, dtype: float64
#
# 2018
# count    100.000000
# mean       0.115569
# std        0.104527
# min        0.023200
# 25%        0.045350
# 50%        0.074950
# 75%        0.137000
# max        0.530000
# Name: speechiness, dtype: float64

# %%
print("Analisa Data acousticness\n")
print("2017")
print(top2017['acousticness'].describe())
print("\n2018")
print(top2018['acousticness'].describe())
# Out:
# Analisa Data acousticness
#
# 2017
# count    100.000000
# mean       0.166306
# std        0.166730
# min        0.000259
# 25%        0.039100
# 50%        0.106500
# 75%        0.231250
# max        0.695000
# Name: acousticness, dtype: float64
#
# 2018
# count    100.000000
# mean       0.195701
# std        0.220946
# min        0.000282
# 25%        0.040225
# 50%        0.109000
# 75%        0.247750
# max        0.934000
# Name: acousticness, dtype: float64

# %%
print("Analisa Data Instrumentalness\n")
print("2017")
print(top2017['instrumentalness'].describe())
print("\n2018")
print(top2018['instrumentalness'].describe())
# Out:
# Analisa Data Instrumentalness
#
# 2017
# count    100.000000
# mean       0.004796
# std        0.026038
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000013
# max        0.210000
# Name: instrumentalness, dtype: float64
#
# 2018
# count    100.000000
# mean       0.001584
# std        0.013449
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000031
# max        0.134000
# Name: instrumentalness, dtype: float64

# %%
print("Analisa Data Liveness\n")
print("2017")
print(top2017['liveness'].describe())
print("\n2018")
print(top2018['liveness'].describe())
# Out:
# Analisa Data Liveness
#
# 2017
# count    100.000000
# mean       0.150607
# std        0.079011
# min        0.042400
# 25%        0.098275
# 50%        0.125000
# 75%        0.179250
# max        0.440000
# Name: liveness, dtype: float64
#
# 2018
# count    100.000000
# mean       0.158302
# std        0.111662
# min        0.021500
# 25%        0.094675
# 50%        0.118500
# 75%        0.170750
# max        0.636000
# Name: liveness, dtype: float64

# %%
print("Analisa Data Valence\n")
print("2017")
print(top2017['valence'].describe())
print("\n2018")
print(top2018['valence'].describe())
# Out:
# Analisa Data Valence
#
# 2017
# count    100.000000
# mean       0.517049
# std        0.216436
# min        0.086200
# 25%        0.375500
# 50%        0.502500
# 75%        0.679000
# max        0.966000
# Name: valence, dtype: float64
#
# 2018
# count    100.000000
# mean       0.484443
# std        0.206145
# min        0.079600
# 25%        0.341000
# 50%        0.470500
# 75%        0.641500
# max        0.931000
# Name: valence, dtype: float64

# %%
print("Analisa Data Tempo\n")
print("2017")
print(top2017['tempo'].describe())
print("\n2018")
print(top2018['tempo'].describe())
# Out:
# Analisa Data Tempo
#
# 2017
# count    100.000000
# mean     119.202460
# std       27.952928
# min       75.016000
# 25%       99.911750
# 50%      112.468000
# 75%      137.166000
# max      199.864000
# Name: tempo, dtype: float64
#
# 2018
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
print("Analisa Data Duration\n")
print("2017")
print(top2017['duration_ms'].describe())
print("\n2018")
print(top2018['duration_ms'].describe())
# Out:
# Analisa Data Duration
#
# 2017
# count       100.00000
# mean     218387.28000
# std       32851.07772
# min      165387.00000
# 25%      198490.50000
# 50%      214106.00000
# 75%      230543.00000
# max      343150.00000
# Name: duration_ms, dtype: float64
#
# 2018
# count       100.000000
# mean     205206.780000
# std       40007.893404
# min       95467.000000
# 25%      184680.000000
# 50%      205047.500000
# 75%      221493.250000
# max      417920.000000
# Name: duration_ms, dtype: float64

# %% [markdown]
# # **Grafik Perbandingan Data**

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Danceability")
ax[0].hist(top2017['danceability'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['danceability'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Energy")
ax[0].hist(top2017['energy'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['energy'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Key")
ax[0].hist(top2017['key'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['key'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Loudness")
ax[0].hist(top2017['loudness'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['loudness'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Mode")
ax[0].hist(top2017['mode'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['mode'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Speechiness")
ax[0].hist(top2017['speechiness'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['speechiness'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Acousticness")
ax[0].hist(top2017['acousticness'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['acousticness'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Instrumentalness")
ax[0].hist(top2017['instrumentalness'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['instrumentalness'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Liveness")
ax[0].hist(top2017['liveness'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['liveness'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Valence")
ax[0].hist(top2017['valence'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['valence'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Tempo")
ax[0].hist(top2017['tempo'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['tempo'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')

# %%
plt.style.use('ggplot')
plt.rcParams.update({'figure.figsize':(10,6), 'figure.dpi':120})
fig,ax = plt.subplots(2)
fig.subplots_adjust(hspace=0.8, wspace=0.6)
fig.suptitle("Duration")
ax[0].hist(top2017['duration_ms'], color='Blue')
ax[0].set_title('2017')
ax[0].set_ylabel('Banyaknya Data')
ax[0].set_xlabel('Index')
ax[1].hist(top2018['duration_ms'], color='Red')
ax[1].set_title('2018')
ax[1].set_ylabel('Banyaknya Data')
ax[1].set_xlabel('Index')
# Out:
# Text(0.5, 0, 'Index')
